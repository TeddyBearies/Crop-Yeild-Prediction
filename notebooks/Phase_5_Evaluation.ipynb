# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
# TODO: Evaluate model results against business success criteria.
# Reference your Phase 1 definitions and Phase 4 results.

evaluation = {
    "business_criteria": [
        {
            "criterion": "Forecast expected yield 3 months before harvest to optimize storage logistics.",
            "target": "Low absolute error supporting macro-planning",
            "achieved": "Mean Absolute Error (MAE) of 0.154 standardized units, showing high predictive capability",
            "met": True
        },
        {
            "criterion": "Identify crop resilience in deficient rainfall.",
            "target": "Variable importance ranking showing climate sensitivity",
            "achieved": "Random Forest successfully learned non-linear interactions between weather and yield",
            "met": True
        }
    ],
    "technical_criteria": [
        {
            "metric": "R-Squared (R2 Score)",
            "target": ">= 0.75",
            "achieved": 0.933, # Hold-out Test Score
            "met": True
        },
        {
            "metric": "Cross-Validation Mean R2",
            "target": "High consistency across folds",
            "achieved": 0.83, # Showed some variability (0.66 to 0.93)
            "met": True
        }
    ],
    "overall_assessment": "The Random Forest model successfully addresses the core business objective by tracking complex weather interactions. However, cross-validation variance indicates prediction quality drops for certain underrepresented geographical zones or extreme climate years.",
    "approved_models": ["Random Forest (Tuned)"],
    "rejected_models": ["Linear Regression (Failed to capture non-linear weather interaction)"]
}

# %%
# Display the evaluation summary
print("=" * 60)
print("EVALUATION AGAINST BUSINESS SUCCESS CRITERIA")
print("=" * 60)
#
print("\n--- Business Criteria ---")
for c in evaluation['business_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['criterion']}")
    print(f"         Target: {c['target']}  |  Achieved: {c['achieved']}")
#
print("\n--- Technical Criteria ---")
for c in evaluation['technical_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"  [{status}] {c['metric']}: Target {c['target']}  |  Achieved: {c['achieved']}")
#
print(f"\nOverall: {evaluation['overall_assessment']}")
print(f"Approved models: {evaluation['approved_models']}")
print(f"Rejected models: {evaluation['rejected_models']}")
# Out:
# ============================================================
# EVALUATION AGAINST BUSINESS SUCCESS CRITERIA
# ============================================================
#
# --- Business Criteria ---
#   [PASS] Forecast expected yield 3 months before harvest to optimize storage logistics.
#          Target: Low absolute error supporting macro-planning  |  Achieved: Mean Absolute Error (MAE) of 0.154 standardized units, showing high predictive capability
#   [PASS] Identify crop resilience in deficient rainfall.
#          Target: Variable importance ranking showing climate sensitivity  |  Achieved: Random Forest successfully learned non-linear interactions between weather and yield
#
# --- Technical Criteria ---
#   [PASS] R-Squared (R2 Score): Target >= 0.75  |  Achieved: 0.933
#   [PASS] Cross-Validation Mean R2: Target High consistency across folds  |  Achieved: 0.83
#
# Overall: The Random Forest model successfully addresses the core business objective by tracking complex weather interactions. However, cross-validation variance indicates prediction quality drops for certain underrepresented geographical zones or extreme climate years.
# Approved models: ['Random Forest (Tuned)']
# Rejected models: ['Linear Regression (Failed to capture non-linear weather interaction)']

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
# TODO: Review the end-to-end process.

process_review = {
    "checklist": [
        {"item": "All relevant data sources were considered",      "status": "Yes", "notes": "Primary dataset was successfully augmented with Wikipedia zone records."},
        {"item": "Data preparation was thorough and documented",   "status": "Yes", "notes": "Modular architecture (src/ scripts) used to standardise cleaning rules."},
        {"item": "No data leakage between train and test sets",    "status": "Yes", "notes": "Train-test split performed prior to hyperparameter tuning and model training."},
        {"item": "Multiple modelling techniques were compared",    "status": "Yes", "notes": "Baseline Linear Regression vs Non-Linear Random Forest."},
        {"item": "Hyperparameters were tuned appropriately",       "status": "Yes", "notes": "GridSearchCV employed using 5-fold cross-validation."},
        {"item": "Results are reproducible (random seeds set)",    "status": "Yes", "notes": "RANDOM_SEED 42 used consistently across the pipeline."},
        {"item": "Bias and fairness have been considered",         "status": "Partial", "notes": "Certain states yield more historical records; national policy models might structurally favour well-represented regions implicitly."},
        {"item": "Ethical implications have been reviewed",        "status": "Yes", "notes": "Model limits decision-support rather than automating logistics unilaterally, mitigating harm."},
    ],
    "overall_quality": "Strong foundational process, but requires constant bias monitoring regarding regional imbalances within the underlying open data.",
    "areas_for_improvement": [
        "Scaling up historical datasets to capture multi-decade resilience behaviour.",
        "Extracting finer spatio-temporal features rather than aggregated yearly averages."
    ]
}

# %%
# Display the process review
print("=== Process Review Checklist ===")
for item in process_review['checklist']:
    print(f"  [{item['status']:^8}] {item['item']}")
    if item['notes']:
        print(f"           Note: {item['notes']}")
#
print(f"\nOverall Quality: {process_review['overall_quality']}")
if process_review['areas_for_improvement']:
    print("Areas for Improvement:")
    for area in process_review['areas_for_improvement']:
        print(f"  - {area}")
# Out:
# === Process Review Checklist ===
#   [  Yes   ] All relevant data sources were considered
#            Note: Primary dataset was successfully augmented with Wikipedia zone records.
#   [  Yes   ] Data preparation was thorough and documented
#            Note: Modular architecture (src/ scripts) used to standardise cleaning rules.
#   [  Yes   ] No data leakage between train and test sets
#            Note: Train-test split performed prior to hyperparameter tuning and model training.
#   [  Yes   ] Multiple modelling techniques were compared
#            Note: Baseline Linear Regression vs Non-Linear Random Forest.
#   [  Yes   ] Hyperparameters were tuned appropriately
#            Note: GridSearchCV employed using 5-fold cross-validation.
#   [  Yes   ] Results are reproducible (random seeds set)
#            Note: RANDOM_SEED 42 used consistently across the pipeline.
#   [Partial ] Bias and fairness have been considered
#            Note: Certain states yield more historical records; national policy models might structurally favour well-represented regions implicitly.
#   [  Yes   ] Ethical implications have been reviewed
#            Note: Model limits decision-support rather than automating logistics unilaterally, mitigating harm.
#
# Overall Quality: Strong foundational process, but requires constant bias monitoring regarding regional imbalances within the underlying open data.
# Areas for Improvement:
#   - Scaling up historical datasets to capture multi-decade resilience behaviour.
#   - Extracting finer spatio-temporal features rather than aggregated yearly averages.

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
# TODO: Determine and document the next steps.

next_steps = {
    "decision": "Proceed to Deployment",
    "rationale": "The Tuned Random Forest model yields practically acceptable error margins suitable for logistics forecasting. While the model has weaknesses in predicting exceptional extreme weather anomalies, it is defensively robust enough for an aggregated regional planning rollout.",
    "if_iterating": {
        "return_to_phase": "",
        "specific_actions": []
    },
    "if_deploying": {
        "selected_model": "Random Forest (Tuned)",
        "deployment_priority": "High"
    }
}

# %%
# Display the decision
print("=" * 60)
print("NEXT STEPS DECISION")
print("=" * 60)
print(f"\nDecision  : {next_steps['decision']}")
print(f"Rationale : {next_steps['rationale']}")
#
if next_steps['decision'] == 'Iterate':
    print(f"\nReturn to: {next_steps['if_iterating']['return_to_phase']}")
    for action in next_steps['if_iterating']['specific_actions']:
        print(f"  - {action}")
elif next_steps['decision'] == 'Proceed to Deployment':
    print(f"\nModel to deploy: {next_steps['if_deploying']['selected_model']}")
    print(f"Priority: {next_steps['if_deploying']['deployment_priority']}")
# Out:
# ============================================================
# NEXT STEPS DECISION
# ============================================================
#
# Decision  : Proceed to Deployment
# Rationale : The Tuned Random Forest model yields practically acceptable error margins suitable for logistics forecasting. While the model has weaknesses in predicting exceptional extreme weather anomalies, it is defensively robust enough for an aggregated regional planning rollout.
#
# Model to deploy: Random Forest (Tuned)
# Priority: High
