# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# Define business objectives here.
business_objectives = {
    "background": "This project is part of the Food and Agriculture Analytics domain, specifically the Crop Yield Prediction section. The broader goal is to optimize crop yields, analyze agricultural data, and monitor food supply chains to improve farming efficiency using predictive modeling.",
    "primary_objective": "Q1 (Business): Forecast the expected yield (Production per Hectare) of Rice and Wheat 3 months before harvest based on rainfall and temperature to optimize storage and logistics planning.\nQ2 (Research): Identify which crop varieties show highest resilience (lowest yield variance) in years with Deficient Rainfall to help suggest which crops may be more suitable in drought-prone districts.",
    "success_criteria": [
        "Develop a reliable pre-harvest regression model predicting production per hectare.",
        "The model should achieve errors low enough to make the predictions useful for planning purposes.",
        "Provide a clear insight into climate resilience to answer the research question."
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#    The project operates within Food and Agriculture Analytics (Section 15.1). The broader goal is to optimize crop yields, analyze agricultural data, and monitor food supply chains to improve farming efficiency using predictive modeling.
#
# >> PRIMARY OBJECTIVE:
#    Q1 (Business): Forecast the expected yield (Production per Hectare) of Rice and Wheat 3 months before harvest based on rainfall and temperature to optimize storage and logistics planning.
# Q2 (Research): Identify which crop varieties show highest resilience (lowest yield variance) in years with Deficient Rainfall to influence policy in drought-prone districts.
#
# >> SUCCESS CRITERIA:
#    - Develop a reliable pre-harvest regression model predicting production per hectare.
#    - Model error margins must be acceptable enough to support real-world storage and logistics planning.
#    - Provide a clear insight into climate resilience to answer the research question.

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# Assess the current situation here.
situation_assessment = {
    "resources": {
        "personnel": ["Data Scientist (Student)"],
        "data_sources": ["Kaggle Indian Agriculture Dataset", "Scraped climate/weather context data"],
        "computing": "Local machine (with Jupyter, Pandas, Scikit-learn)",
        "software": ["Python 3", "Pandas", "Scikit-learn", "BeautifulSoup", "Joblib"]
    },
    "requirements": ["Must follow CRISP-DM", "Maximum 1500-word report", "Private GitHub with regular commits"],
    "assumptions": ["Dataset captures reality adequately", "Missing values are manageable"],
    "constraints": ["40-hour estimated workload", "Pandas used for data handling initially, but needs Big Data context"],
    "risks_and_contingencies": [
        {"risk": "Dirty data", "probability": "High", "mitigation": "Rigorous data audit and cleaning via src/ scripts"}
    ],
    "terminology": {
        "Expected Yield": "Production value divided by Area (Hectare)"
    },
    "cost_benefit": "The project has academic value because it applies CRISP-DM to a real agricultural prediction problem and also has practical relevance for planning storage and logistics"
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Data Scientist (Student)"
#     ],
#     "data_sources": [
#       "Kaggle Indian Agriculture Dataset",
#       "Scraped climate/weather context data"
#     ],
#     "computing": "Local machine (with Jupyter, Pandas, Scikit-learn)",
#     "software": [
#       "Python 3",
#       "Pandas",
#       "Scikit-learn",
#       "BeautifulSoup",
#       "Joblib"
#     ]
#   },
#   "requirements": [
#     "Must follow CRISP-DM",
#     "Maximum 1500-word report",
#     "Private GitHub with regular commits"
#   ],
#   "assumptions": [
#     "Dataset captures reality adequately",
#     "Missing values are manageable"
#   ],
#   "constraints": [
#     "40-hour estimated workload",
#     "Pandas used for data handling initially, but needs Big Data context"
#   ],
#   "risks_and_contingencies": [
#     {
#       "risk": "Dirty data",
#       "probability": "High",
#       "mitigation": "Rigorous data audit and cleaning via src/ scripts"
#     }
#   ],
#   "terminology": {
#     "Expected Yield": "Production value divided by Area (Hectare)"
#   },
#   "cost_benefit": "Academic project: High benefit to student learning and grade."
# }

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
# Define data mining goals here.
data_mining_goals = {
    "problem_type": "Regression",
    "target_variable": "yield_per_hectare",
    "technical_goals": [
        "Build a regression model to predict yield_per_hectare for Rice and Wheat.",
        "Conduct exploratory data analysis to identify significant correlations between rainfall, temperature and yield variance."
    ],
    "success_metrics": [
        "Mean Absolute Error (MAE)",
        "Root Mean Squared Error (RMSE)",
        "R-squared (R2 Score)"
    ]
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ============================================================
# BUSINESS TO DATA MINING GOAL MAPPING
# ============================================================
#
# Business Objective : Q1 (Business): Forecast the expected yield (Production per Hectare) of Rice and Wheat 3 months before harvest based on rainfall and temperature to optimize storage and logistics planning.
# Q2 (Research): Identify which crop varieties show highest resilience (lowest yield variance) in years with Deficient Rainfall to influence policy in drought-prone districts.
# Problem Type       : Regression
# Target Variable    : yield_per_hectare
#
# Technical Goals:
#   - Build a regression model to predict yield_per_hectare for Rice and Wheat.
#   - Conduct exploratory data analysis to identify significant correlations between rainfall, temperature and yield variance.
#
# Success Metrics:
#   - Mean Absolute Error (MAE)
#   - Root Mean Squared Error (RMSE)
#   - R-squared (R2 Score)

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
# Produce your project plan here.
project_plan = {
    "tools": ["pandas", "numpy", "matplotlib", "seaborn", "scikit-learn", "requests", "beautifulsoup4"],
    "techniques": ["Linear Regression", "Random Forest Regressor", "Data Scraping and Merging", "Hyperparameter Tuning"],
    "timeline": [
        {"phase": "Data Understanding", "duration": "Next", "status": "Pending"},
        {"phase": "Data Preparation", "duration": "Upcoming", "status": "Pending"},
        {"phase": "Modelling", "duration": "Upcoming", "status": "Pending"},
        {"phase": "Evaluation", "duration": "Upcoming", "status": "Pending"},
        {"phase": "Deployment", "duration": "Upcoming", "status": "Pending"}
    ],
    "dependencies": ["Dataset parsing and successful web scraping"],
    "tool_justification": "Pandas is sufficient for current computational complexity, but will discuss Spark for 10TB scale."
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ============================================================
# PROJECT PLAN
# ============================================================
#
# Tools: pandas, numpy, matplotlib, seaborn, scikit-learn, requests, beautifulsoup4
# Techniques: Linear Regression, Random Forest Regressor, Data Scraping and Merging, Hyperparameter Tuning
#
# Timeline:
#   [  Pending   ] Data Understanding        | Next
#   [  Pending   ] Data Preparation          | Upcoming
#   [  Pending   ] Modelling                 | Upcoming
#   [  Pending   ] Evaluation                | Upcoming
#   [  Pending   ] Deployment                | Upcoming
#
# Dependencies:
#   - Dataset parsing and successful web scraping
#
# Tool Justification: Pandas is sufficient for current computational complexity, but will discuss Spark for 10TB scale.

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ============================================================
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ============================================================
#
# Primary Objective  : Q1 (Business): Forecast the expected yield (Production per Hectare) of Rice and Wheat 3 months before harvest based on rainfall and temperature to optimize storage and logistics planning.
# Q2 (Research): Identify which crop varieties show highest resilience (lowest yield variance) in years with Deficient Rainfall to influence policy in drought-prone districts.
# Problem Type       : Regression
# Target Variable    : yield_per_hectare
# Tools Planned      : pandas, numpy, matplotlib, seaborn, scikit-learn, requests, beautifulsoup4
# Techniques Planned : Linear Regression, Random Forest Regressor, Data Scraping and Merging, Hyperparameter Tuning
